# %% [markdown]
# <a href="https://colab.research.google.com/github/faranak5171/Computer-Vision-Projects/blob/main/Object-Detection/Template_Matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
 # Template Matching - we have a part of an image and want to match it

fig = plt.figure(figsize=(20,15))
rows = 2
cols = 6

def display_img(num,img,title):
  ax = fig.add_subplot(rows, cols, num)
  ax.imshow(img)
  ax.set_title(title)

full = cv2.imread('sammy.jpg')
full = cv2.cvtColor(full, cv2.COLOR_BGR2RGB)

face = cv2.imread('sammy_face.jpg')
face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
 
display_img(1, full, 'Main Image')
display_img(2, face, 'Template')

print("Shape of original image:",full.shape)
print("Shape of template:",face.shape)

# All the 6 methods for comparison in a list
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR', 'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']
for i, m in enumerate(methods):
  # Create a copy of image
  full_copy = full.copy()
  method = eval(m)
  # Template matching
  result = cv2.matchTemplate(full_copy, face,method)
  # show result
  display_img(i+3,result,str(m))
# Out:
# Shape of original image: (1367, 1025, 3)
# Shape of template: (375, 486, 3)

# %%
mystring = 'sum'
myfunc = eval(mystring)
myfunc([1,2,3])
# Out:
# 6
