# %%
import cv2
import numpy as np

import plotimages

# %%
'''
    Contour Detection - a curve joining al the continuous points
'''

figures = plotimages.plotimages(1,3)

img = cv2.imread('internal_external.png',0)
plotimages.display_img(figures, img, 'Original Image', 'gray')

contours,hierarchy = cv2.findContours(img,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)
external_contours = np.zeros(img.shape)
internal_contours = np.zeros(img.shape)
for i in range(len(contours)):
    if hierarchy[0][i][3] == -1:
        # external contour
        cv2.drawContours(external_contours,contours,i,255,-1)
    else:
        cv2.drawContours(internal_contours,contours,i,255,-1)

plotimages.display_img(figures, external_contours, 'External contours','gray')
plotimages.display_img(figures, internal_contours, 'Internal contours','gray')

# %%
hierarchy
# Out:
# array([[[ 4, -1,  1, -1],
#         [ 2, -1, -1,  0],
#         [ 3,  1, -1,  0],
#         [-1,  2, -1,  0],
#         [21,  0,  5, -1],
#         [ 6, -1, -1,  4],
#         [ 7,  5, -1,  4],
#         [ 8,  6, -1,  4],
#         [ 9,  7, -1,  4],
#         [10,  8, -1,  4],
#         [11,  9, -1,  4],
#         [12, 10, -1,  4],
#         [13, 11, -1,  4],
#         [14, 12, -1,  4],
#         [15, 13, -1,  4],
#         [16, 14, -1,  4],
#         [17, 15, -1,  4],
#         [18, 16, -1,  4],
#         [19, 17, -1,  4],
#         [20, 18, -1,  4],
#         [-1, 19, -1,  4],
#         [-1,  4, -1, -1]]], dtype=int32)
